# %%
from src.config import PainfaceReaderConfig
from src.datasets.painfacereader import load_units
from src.preprocess import preprocess, build_detector

cfg = PainfaceReaderConfig(root="/Volumes/painfacereader.kogsys/Datensatz_MSE_Hauptstudie_Loy", view="frontal")
units, au_names = load_units(cfg)
# Out:
# Loading Samples:   0%|          | 0/3359 [00:00<?, ?People/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 from src.datasets.painfacereader import load_units
#       3 from src.preprocess import preprocess, build_detector
#       4
#       5 cfg = PainfaceReaderConfig(root="/Volumes/painfacereader.kogsys/Datensatz_MSE_Hauptstudie_Loy", view="frontal")
# ----> 6 units, au_names = load_units(cfg)
#
# File ~/Documents/PROJECTS/au-detection/src/datasets/painfacereader.py:109, in load_units(config)
#     106     n_wrong_view += 1
#     107     continue
# --> 109 df = read_csv_smart(ann_path, sep=";")
#     110 df.columns = [str(c).strip() for c in df.columns]
#     111 if au_names is None:
#
# File ~/Documents/PROJECTS/au-detection/src/datasets/utils.py:78, in read_csv_smart(path, sep)
#      76 for enc in ("utf-8", "utf-8-sig", "latin-1"):
# ...

# %%
preprocess(units, "crops", out_size=224, margin=0.15, detector=build_detector("mps"))
